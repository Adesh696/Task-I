# %% [markdown]
# #YOLOv8 Object Detection on a Custom Dataset

# %% [markdown]
# ##Install YOLOv8 via pip

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 9.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/person.v1i.yolov8.zip
# !unzip /content/gdrive/MyDrive/runs.zip
# Out:
# Archive:  /content/gdrive/MyDrive/runs.zip
#    creating: content/runs/
#    creating: content/runs/detect/
#    creating: content/runs/detect/train/
#   inflating: content/runs/detect/train/labels.jpg
#   inflating: content/runs/detect/train/train_batch2.jpg
#   inflating: content/runs/detect/train/labels_correlogram.jpg
#   inflating: content/runs/detect/train/val_batch2_pred.jpg
#   inflating: content/runs/detect/train/confusion_matrix_normalized.png
#   inflating: content/runs/detect/train/val_batch2_labels.jpg
#   inflating: content/runs/detect/train/val_batch0_labels.jpg
#   inflating: content/runs/detect/train/train_batch0.jpg
#   inflating: content/runs/detect/train/val_batch1_pred.jpg
#    creating: content/runs/detect/train/weights/
#   inflating: content/runs/detect/train/weights/last.pt
#   inflating: content/runs/detect/train/weights/best.pt
#   inflating: content/runs/detect/train/F1_curve.png
# ...

# %%
from ultralytics import YOLO

# model = YOLO("yolo")
model = YOLO('yolov8n.pt')

# %%
# !nvidia-smi
# Out:
# Tue Nov 21 15:17:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/data.yaml epochs=90 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 206MB/s]
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/content/content/runs/detect/train/weights/best.pt \
data=/content/data.yaml
# Out:
# Ultralytics YOLOv8.0.217 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 4.33MB/s]
# val: Scanning /content/valid/labels... 870 images, 0 backgrounds, 0 corrupt: 100% 870/870 [00:00<00:00, 2184.80it/s]
# val: New cache created: /content/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 55/55 [00:18<00:00,  2.95it/s]
#                    all        870       2100       0.89      0.781      0.864      0.598
# Speed: 0.6ms preprocess, 8.8ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/content/runs/detect/train/weights/best.pt conf = 0.25 source = /content/test/images/
#data=/content/data.yaml
# check the results in predict folder
# Out:
# Ultralytics YOLOv8.0.217 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/432 /content/test/images/0502_hotels-homeless-housing01_jpg.rf.dde03ce4d3c267c5fc1bfcf830f384cb.jpg: 640x640 2 0- Persons, 17.0ms
# image 2/432 /content/test/images/1239839_jpg.rf.987facec13ebd2d47b1a2b897293efea.jpg: 640x640 4 0- Persons, 34.2ms
# image 3/432 /content/test/images/1496724_jpg.rf.c0ae1748174f149929e34ea0e9ba7a82.jpg: 640x640 4 0- Persons, 16.3ms
# image 4/432 /content/test/images/15885433622549_jpg.rf.aba7bc103d5bc7d00efa9793b4df94cc.jpg: 640x640 14 0- Persons, 16.2ms
# image 5/432 /content/test/images/16076206684034_jpg.rf.0f79d091ff61f34b539e64bdb6f64b5f.jpg: 640x640 6 0- Persons, 16.2ms
# image 6/432 /content/test/images/2020-03-03_11-03-08___2925_jpg.rf.34a3cd362e00b008be9cc958ca2adbfe.jpg: 640x640 3 0- Persons, 16.4ms
# ...

# %%
  # %cp -r /content/runs/detect/predict2 /content/content/runs/detect

# %%
# !yolo task=detect mode=predict model=/content/content/runs/detect/train/weights/best.pt conf = 0.25 source = /content/gdrive/MyDrive/Task2_test_videos/
# Check the results in predict2 folder
# Out:
# Streaming output truncated to the last 5000 lines.
# video 3/5 (168/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 7.9ms
# video 3/5 (169/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 8.2ms
# video 3/5 (170/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 7.9ms
# video 3/5 (171/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 7.9ms
# video 3/5 (172/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 8.1ms
# video 3/5 (173/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 7.9ms
# video 3/5 (174/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 8.1ms
# video 3/5 (175/596) /content/gdrive/MyDrive/Task2_test_videos/people-detection.mp4: 384x640 (no detections), 12.3ms
# ...

# %%
# %cp -r /content/runs/detect/* /content/content/runs/detect

# %%
import shutil

# Replace 'folder_path' with the path of the folder you want to zip
folder_path = '/content/content/runs'

# Replace 'output_zip_path' with the desired path and name for the output zip file
output_zip_path = '/content/runs'

shutil.make_archive(output_zip_path, 'zip', folder_path)
# Out:
# '/content/runs.zip'

# %%
from google.colab import drive

drive.mount('/content/gdrive')

import shutil

# Replace 'source_file_path' with the path of the file in Colab
source_file_path = '/content/runs.zip'

# Replace 'destination_drive_path' with the destination path in Google Drive
destination_drive_path = '/content/gdrive/MyDrive/Task2_test_videos/runz.zip'

shutil.copy(source_file_path, destination_drive_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '/content/gdrive/MyDrive/Task2_test_videos/runz.zip'
